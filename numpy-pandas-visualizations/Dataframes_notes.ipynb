# %% [markdown]
# # Dataframes:
# #### - Dataframes represent tabular, 2-dimensional data, and provide a number of facilities for manipulating and transforming the data.

# %%
import pandas as pd
import numpy as np

np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here

math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
## a dataframe is composed of series
# each series is a column
#but the df itself is more than a list of series
#the df itself has its own functionality on top

# %%
#df.column_name returns that specific series
df.name
# Out:
# 0       Sally
# 1        Jane
# 2       Suzie
# 3       Billy
# 4         Ada
# 5        John
# 6      Thomas
# 7       Marie
# 8      Albert
# 9     Richard
# 10      Isaac
# 11       Alan
# Name: name, dtype: object

# %%
#the df itself has its own method and functionality
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     12 non-null     object
#  1   math     12 non-null     int64
#  2   english  12 non-null     int64
#  3   reading  12 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 512.0+ bytes

# %%
df.columns #looking at columns & index
# Out:
# Index(['name', 'math', 'english', 'reading'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
#.describe provides summary stats on our numeric columns
df.describe()
# Out:
#             math    english    reading
# count  12.000000  12.000000  12.000000
# mean   84.833333  77.666667  86.500000
# std    11.134168  13.371158   9.643651
# min    62.000000  62.000000  67.000000
# 25%    78.500000  63.750000  80.750000
# 50%    90.000000  77.500000  89.000000
# 75%    92.250000  86.750000  93.250000
# max    98.000000  99.000000  98.000000

# %% [markdown]
# ## Why DataFrames?
# ### -Rectangular data consisting of columns and rows
# ### -Dataframes enjoy functionality above/beyond series
# ### -Dataframes are a container for series

# %%
df.columns = [column.upper() for column in df.columns]
df
# Out:
#        NAME  MATH  ENGLISH  READING
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
df.index = df.NAME

df
# Out:
#             NAME  MATH  ENGLISH  READING
# NAME
# Sally      Sally    62       85       80
# Jane        Jane    88       79       67
# Suzie      Suzie    94       74       95
# Billy      Billy    98       96       88
# Ada          Ada    77       92       98
# John        John    79       76       93
# Thomas    Thomas    82       64       81
# Marie      Marie    93       63       90
# Albert    Albert    92       62       87
# Richard  Richard    69       80       94
# Isaac      Isaac    92       99       93
# Alan        Alan    92       62       72

# %%
##no index was named/set, so defaults to numeric (see code at top)
##index can be the name of lists in df, 

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades}, index=students)

# %%
df
# Out:
#             name  math  english  reading
# Sally      Sally    62       85       80
# Jane        Jane    88       79       67
# Suzie      Suzie    94       74       95
# Billy      Billy    98       96       88
# Ada          Ada    77       92       98
# John        John    79       76       93
# Thomas    Thomas    82       64       81
# Marie      Marie    93       63       90
# Albert    Albert    92       62       87
# Richard  Richard    69       80       94
# Isaac      Isaac    92       99       93
# Alan        Alan    92       62       72

# %%
## How to access a specific column?
#df.column_name
# or df.['column_name']

df['math']
# Out:
# Sally      62
# Jane       88
# Suzie      94
# Billy      98
# Ada        77
# John       79
# Thomas     82
# Marie      93
# Albert     92
# Richard    69
# Isaac      92
# Alan       92
# Name: math, dtype: int64

# %%
df.math
# Out:
# Sally      62
# Jane       88
# Suzie      94
# Billy      98
# Ada        77
# John       79
# Thomas     82
# Marie      93
# Albert     92
# Richard    69
# Isaac      92
# Alan       92
# Name: math, dtype: int64

# %%
## making a NEW column, we need to use the ['column_name'] syntax

#df.['column_name'] = value

df['cohort'] = 'Jemison'
df
# Out:
#             name  math  english  reading   cohort
# Sally      Sally    62       85       80  Jemison
# Jane        Jane    88       79       67  Jemison
# Suzie      Suzie    94       74       95  Jemison
# Billy      Billy    98       96       88  Jemison
# Ada          Ada    77       92       98  Jemison
# John        John    79       76       93  Jemison
# Thomas    Thomas    82       64       81  Jemison
# Marie      Marie    93       63       90  Jemison
# Albert    Albert    92       62       87  Jemison
# Richard  Richard    69       80       94  Jemison
# Isaac      Isaac    92       99       93  Jemison
# Alan        Alan    92       62       72  Jemison

# %%
df['campus'] = 'San Antonio'
df
# Out:
#             name  math  english  reading   cohort       campus
# Sally      Sally    62       85       80  Jemison  San Antonio
# Jane        Jane    88       79       67  Jemison  San Antonio
# Suzie      Suzie    94       74       95  Jemison  San Antonio
# Billy      Billy    98       96       88  Jemison  San Antonio
# Ada          Ada    77       92       98  Jemison  San Antonio
# John        John    79       76       93  Jemison  San Antonio
# Thomas    Thomas    82       64       81  Jemison  San Antonio
# Marie      Marie    93       63       90  Jemison  San Antonio
# Albert    Albert    92       62       87  Jemison  San Antonio
# Richard  Richard    69       80       94  Jemison  San Antonio
# Isaac      Isaac    92       99       93  Jemison  San Antonio
# Alan        Alan    92       62       72  Jemison  San Antonio

# %%
#now we can call from the df via columns
#df.math >= 90 returns a series of booleans
df.math >= 90
# Out:
# Sally      False
# Jane       False
# Suzie       True
# Billy       True
# Ada        False
# John       False
# Thomas     False
# Marie       True
# Albert      True
# Richard    False
# Isaac       True
# Alan        True
# Name: math, dtype: bool

# %% [markdown]
# ## Once you have your array/Series of booleans, you have the keys to the castle
#
# -we can filter our results
#
# -'df[df.column > 90]'

# %%
df[df.math > 90]
# Out:
#           name  math  english  reading   cohort       campus
# Suzie    Suzie    94       74       95  Jemison  San Antonio
# Billy    Billy    98       96       88  Jemison  San Antonio
# Marie    Marie    93       63       90  Jemison  San Antonio
# Albert  Albert    92       62       87  Jemison  San Antonio
# Isaac    Isaac    92       99       93  Jemison  San Antonio
# Alan      Alan    92       62       72  Jemison  San Antonio

# %%
# Let's try other filters...
## What if we need to store math >= 90 as its own column?

df['math_honors'] = df.math >= 90
df
# Out:
#             name  math  english  reading   cohort       campus  math__honors  \
# Sally      Sally    62       85       80  Jemison  San Antonio         False
# Jane        Jane    88       79       67  Jemison  San Antonio         False
# Suzie      Suzie    94       74       95  Jemison  San Antonio          True
# Billy      Billy    98       96       88  Jemison  San Antonio          True
# Ada          Ada    77       92       98  Jemison  San Antonio         False
# John        John    79       76       93  Jemison  San Antonio         False
# Thomas    Thomas    82       64       81  Jemison  San Antonio         False
# Marie      Marie    93       63       90  Jemison  San Antonio          True
# Albert    Albert    92       62       87  Jemison  San Antonio          True
# Richard  Richard    69       80       94  Jemison  San Antonio         False
# Isaac      Isaac    92       99       93  Jemison  San Antonio          True
# Alan        Alan    92       62       72  Jemison  San Antonio          True
#
#          english_honors  math_honors
# Sally             False        False
# Jane              False        False
# Suzie             False         True
# Billy              True         True
# Ada                True        False
# John              False        False
# Thomas            False        False
# Marie             False         True
# Albert            False         True
# Richard           False        False
# Isaac              True         True
# Alan              False         True

# %%
df['english_honors'] = df.english >= 90
df
# Out:
#             name  math  english  reading   cohort       campus  math__honors  \
# Sally      Sally    62       85       80  Jemison  San Antonio         False
# Jane        Jane    88       79       67  Jemison  San Antonio         False
# Suzie      Suzie    94       74       95  Jemison  San Antonio          True
# Billy      Billy    98       96       88  Jemison  San Antonio          True
# Ada          Ada    77       92       98  Jemison  San Antonio         False
# John        John    79       76       93  Jemison  San Antonio         False
# Thomas    Thomas    82       64       81  Jemison  San Antonio         False
# Marie      Marie    93       63       90  Jemison  San Antonio          True
# Albert    Albert    92       62       87  Jemison  San Antonio          True
# Richard  Richard    69       80       94  Jemison  San Antonio         False
# Isaac      Isaac    92       99       93  Jemison  San Antonio          True
# Alan        Alan    92       62       72  Jemison  San Antonio          True
#
#          english_honors  math_honors
# Sally             False        False
# Jane              False        False
# Suzie             False         True
# Billy              True         True
# Ada                True        False
# John              False        False
# Thomas            False        False
# Marie             False         True
# Albert            False         True
# Richard           False        False
# Isaac              True         True
# Alan              False         True

# %%
## What about creating an all_honors column?
# we can use past columns that already state boolean of True to add together as like an if, and statement
df['all_honors'] = df.english_honors & df.math_honors

#the above would be identitical to if we put (df.english >= 90) & (df.math >= 90)

df.head()
# Out:
#         name  math  english  reading   cohort       campus  math__honors  \
# Sally  Sally    62       85       80  Jemison  San Antonio         False
# Jane    Jane    88       79       67  Jemison  San Antonio         False
# Suzie  Suzie    94       74       95  Jemison  San Antonio          True
# Billy  Billy    98       96       88  Jemison  San Antonio          True
# Ada      Ada    77       92       98  Jemison  San Antonio         False
#
#        english_honors  math_honors  all_honors
# Sally           False        False       False
# Jane            False        False       False
# Suzie           False         True       False
# Billy            True         True        True
# Ada              True        False       False

# %%
df['overall_average'] = (df.math + df.english) / 2

df.head()
# Out:
#         name  math  english  reading   cohort       campus  math__honors  \
# Sally  Sally    62       85       80  Jemison  San Antonio         False
# Jane    Jane    88       79       67  Jemison  San Antonio         False
# Suzie  Suzie    94       74       95  Jemison  San Antonio          True
# Billy  Billy    98       96       88  Jemison  San Antonio          True
# Ada      Ada    77       92       98  Jemison  San Antonio         False
#
#        english_honors  math_honors  all_honors  overall_average
# Sally           False        False       False             73.5
# Jane            False        False       False             83.5
# Suzie           False         True       False             84.0
# Billy            True         True        True             97.0
# Ada              True        False       False             84.5

# %%
## to view only a specific set of columns:
columns = ['name', 'math', 'reading', 'english']

df[columns].head()
# Out:
#         name  math  reading  english
# Sally  Sally    62       80       85
# Jane    Jane    88       67       79
# Suzie  Suzie    94       95       74
# Billy  Billy    98       88       96
# Ada      Ada    77       98       92

# %%
## double brackets produce the same result as above w/o a variable
df[['name','math', 'reading', 'english']]
# Out:
#             name  math  reading  english
# Sally      Sally    62       80       85
# Jane        Jane    88       67       79
# Suzie      Suzie    94       95       74
# Billy      Billy    98       88       96
# Ada          Ada    77       98       92
# John        John    79       93       76
# Thomas    Thomas    82       81       64
# Marie      Marie    93       90       63
# Albert    Albert    92       87       62
# Richard  Richard    69       94       80
# Isaac      Isaac    92       93       99
# Alan        Alan    92       72       62

# %%
# How to drop columns
cols_to_drop = ['campus','cohort', 'math__honors']

df.drop(columns = cols_to_drop)
df.head()
# Out:
#         name  math  english  reading   cohort       campus  math__honors  \
# Sally  Sally    62       85       80  Jemison  San Antonio         False
# Jane    Jane    88       79       67  Jemison  San Antonio         False
# Suzie  Suzie    94       74       95  Jemison  San Antonio          True
# Billy  Billy    98       96       88  Jemison  San Antonio          True
# Ada      Ada    77       92       98  Jemison  San Antonio         False
#
#        english_honors  math_honors  all_honors  overall_average
# Sally           False        False       False             73.5
# Jane            False        False       False             83.5
# Suzie           False         True       False             84.0
# Billy            True         True        True             97.0
# Ada              True        False       False             84.5

# %%
# If you have a series/arrays of booleans, you can filter your results!!

df[df.name == 'Jane']
# Out:
#       name  math  english  reading   cohort       campus  math__honors  \
# Jane  Jane    88       79       67  Jemison  San Antonio         False
#
#       english_honors  math_honors  all_honors  overall_average
# Jane           False        False       False             83.5

# %%
df[(df.name == 'Jane') | (df.name == 'Marie')]
# Out:
#         name  math  english  reading   cohort       campus  math__honors  \
# Jane    Jane    88       79       67  Jemison  San Antonio         False
# Marie  Marie    93       63       90  Jemison  San Antonio          True
#
#        english_honors  math_honors  all_honors  overall_average
# Jane            False        False       False             83.5
# Marie           False         True       False             78.0

# %%
## The | or & operators here return a series of booleans
(df.name == 'Jane') | (df.name == 'Marie')
# Out:
# Sally      False
# Jane        True
# Suzie      False
# Billy      False
# Ada        False
# John       False
# Thomas     False
# Marie       True
# Albert     False
# Richard    False
# Isaac      False
# Alan       False
# Name: name, dtype: bool

# %%
## The code that produces the series of boolean goes in the square braces
df[df.name.str.startswith('S')]
# Out:
#         name  math  english  reading   cohort       campus  math__honors  \
# Sally  Sally    62       85       80  Jemison  San Antonio         False
# Suzie  Suzie    94       74       95  Jemison  San Antonio          True
#
#        english_honors  math_honors  all_honors  overall_average
# Sally           False        False       False             73.5
# Suzie           False         True       False             84.0

# %%
#Sorting
df.sort_values(by='english') #defaults are ascending order
# Out:
#             name  math  english  reading   cohort       campus  math__honors  \
# Albert    Albert    92       62       87  Jemison  San Antonio          True
# Alan        Alan    92       62       72  Jemison  San Antonio          True
# Marie      Marie    93       63       90  Jemison  San Antonio          True
# Thomas    Thomas    82       64       81  Jemison  San Antonio         False
# Suzie      Suzie    94       74       95  Jemison  San Antonio          True
# John        John    79       76       93  Jemison  San Antonio         False
# Jane        Jane    88       79       67  Jemison  San Antonio         False
# Richard  Richard    69       80       94  Jemison  San Antonio         False
# Sally      Sally    62       85       80  Jemison  San Antonio         False
# Ada          Ada    77       92       98  Jemison  San Antonio         False
# Billy      Billy    98       96       88  Jemison  San Antonio          True
# Isaac      Isaac    92       99       93  Jemison  San Antonio          True
#
#          english_honors  math_honors  all_honors  overall_average
# Albert            False         True       False             77.0
# Alan              False         True       False             77.0
# Marie             False         True       False             78.0
# Thomas            False        False       False             73.0
# Suzie             False         True       False             84.0
# John              False        False       False             77.5
# Jane              False        False       False             83.5
# Richard           False        False       False             74.5
# Sally             False        False       False             73.5
# Ada                True        False       False             84.5
# Billy              True         True        True             97.0
# Isaac              True         True        True             95.5

# %%
df.sort_values(by='english', ascending = False)
# Out:
#             name  math  english  reading   cohort       campus  math__honors  \
# Isaac      Isaac    92       99       93  Jemison  San Antonio          True
# Billy      Billy    98       96       88  Jemison  San Antonio          True
# Ada          Ada    77       92       98  Jemison  San Antonio         False
# Sally      Sally    62       85       80  Jemison  San Antonio         False
# Richard  Richard    69       80       94  Jemison  San Antonio         False
# Jane        Jane    88       79       67  Jemison  San Antonio         False
# John        John    79       76       93  Jemison  San Antonio         False
# Suzie      Suzie    94       74       95  Jemison  San Antonio          True
# Thomas    Thomas    82       64       81  Jemison  San Antonio         False
# Marie      Marie    93       63       90  Jemison  San Antonio          True
# Albert    Albert    92       62       87  Jemison  San Antonio          True
# Alan        Alan    92       62       72  Jemison  San Antonio          True
#
#          english_honors  math_honors  all_honors  overall_average
# Isaac              True         True        True             95.5
# Billy              True         True        True             97.0
# Ada                True        False       False             84.5
# Sally             False        False       False             73.5
# Richard           False        False       False             74.5
# Jane              False        False       False             83.5
# John              False        False       False             77.5
# Suzie             False         True       False             84.0
# Thomas            False        False       False             73.0
# Marie             False         True       False             78.0
# Albert            False         True       False             77.0
# Alan              False         True       False             77.0

# %%
df.sort_values(by=['english', 'math'])
# Out:
#             name  math  english  reading   cohort       campus  math__honors  \
# Albert    Albert    92       62       87  Jemison  San Antonio          True
# Alan        Alan    92       62       72  Jemison  San Antonio          True
# Marie      Marie    93       63       90  Jemison  San Antonio          True
# Thomas    Thomas    82       64       81  Jemison  San Antonio         False
# Suzie      Suzie    94       74       95  Jemison  San Antonio          True
# John        John    79       76       93  Jemison  San Antonio         False
# Jane        Jane    88       79       67  Jemison  San Antonio         False
# Richard  Richard    69       80       94  Jemison  San Antonio         False
# Sally      Sally    62       85       80  Jemison  San Antonio         False
# Ada          Ada    77       92       98  Jemison  San Antonio         False
# Billy      Billy    98       96       88  Jemison  San Antonio          True
# Isaac      Isaac    92       99       93  Jemison  San Antonio          True
#
#          english_honors  math_honors  all_honors  overall_average
# Albert            False         True       False             77.0
# Alan              False         True       False             77.0
# Marie             False         True       False             78.0
# Thomas            False        False       False             73.0
# Suzie             False         True       False             84.0
# John              False        False       False             77.5
# Jane              False        False       False             83.5
# Richard           False        False       False             74.5
# Sally             False        False       False             73.5
# Ada                True        False       False             84.5
# Billy              True         True        True             97.0
# Isaac              True         True        True             95.5

# %%
#to reassign, just rename df with what looking at

df = df.sort_values(by=['english', 'math'])

# %% [markdown]
# ## Chaining methods on a dataframe
# -As long as your method returns a df, you can attach another method
# -Think of string method chaining

# %%
"bANanA".swapcase().lower().swapcase()
# Out:
# 'BANANA'

# %%
df.sort_values(by = 'all_honors').sort_values(by = 'name')
# Out:
#             name  math  english  reading   cohort       campus  math__honors  \
# Ada          Ada    77       92       98  Jemison  San Antonio         False
# Alan        Alan    92       62       72  Jemison  San Antonio          True
# Albert    Albert    92       62       87  Jemison  San Antonio          True
# Billy      Billy    98       96       88  Jemison  San Antonio          True
# Isaac      Isaac    92       99       93  Jemison  San Antonio          True
# Jane        Jane    88       79       67  Jemison  San Antonio         False
# John        John    79       76       93  Jemison  San Antonio         False
# Marie      Marie    93       63       90  Jemison  San Antonio          True
# Richard  Richard    69       80       94  Jemison  San Antonio         False
# Sally      Sally    62       85       80  Jemison  San Antonio         False
# Suzie      Suzie    94       74       95  Jemison  San Antonio          True
# Thomas    Thomas    82       64       81  Jemison  San Antonio         False
#
#          english_honors  math_honors  all_honors  overall_average
# Ada                True        False       False             84.5
# Alan              False         True       False             77.0
# Albert            False         True       False             77.0
# Billy              True         True        True             97.0
# Isaac              True         True        True             95.5
# Jane              False        False       False             83.5
# John              False        False       False             77.5
# Marie             False         True       False             78.0
# Richard           False        False       False             74.5
# Sally             False        False       False             73.5
# Suzie             False         True       False             84.0
# Thomas            False        False       False             73.0

# %%
##remember:
#Methods execute from left to right
#Functions execute from inside out (right to left)

# %%
# Renaming a column using a dictionary
cols_to_rename = {
    "math": "math_grade",
    "reading": "reading_grade",
    "english": "english_grade"
}
cols_to_rename
# Out:
# {'math': 'math_grade', 'reading': 'reading_grade', 'english': 'english_grade'}

# %%
df = df.rename(columns=cols_to_rename)

# %%
df
# Out:
#             name  math_grade  english_grade  reading_grade   cohort  \
# Albert    Albert          92             62             87  Jemison
# Alan        Alan          92             62             72  Jemison
# Marie      Marie          93             63             90  Jemison
# Thomas    Thomas          82             64             81  Jemison
# Suzie      Suzie          94             74             95  Jemison
# John        John          79             76             93  Jemison
# Jane        Jane          88             79             67  Jemison
# Richard  Richard          69             80             94  Jemison
# Sally      Sally          62             85             80  Jemison
# Ada          Ada          77             92             98  Jemison
# Billy      Billy          98             96             88  Jemison
# Isaac      Isaac          92             99             93  Jemison
#
#               campus  math__honors  english_honors  math_honors  all_honors  \
# Albert   San Antonio          True           False         True       False
# Alan     San Antonio          True           False         True       False
# Marie    San Antonio          True           False         True       False
# Thomas   San Antonio         False           False        False       False
# Suzie    San Antonio          True           False         True       False
# John     San Antonio         False           False        False       False
# Jane     San Antonio         False           False        False       False
# Richard  San Antonio         False           False        False       False
# Sally    San Antonio         False           False        False       False
# Ada      San Antonio         False            True        False       False
# Billy    San Antonio          True            True         True        True
# Isaac    San Antonio          True            True         True        True
#
#          overall_average
# Albert              77.0
# Alan                77.0
# Marie               78.0
# Thomas              73.0
# Suzie               84.0
# John                77.5
# Jane                83.5
# Richard             74.5
# Sally               73.5
# Ada                 84.5
# Billy               97.0
# Isaac               95.5
